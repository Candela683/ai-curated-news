# %%
# !python C:\code\news\ai-curated-news\backend\gdelt_rss_ETL.py
# Out:
# Batch published_at: 2026-03-27T06:37:12Z
# Rows before type filter: 4813, after: 301
# Type counts:
#  type
# Quality newspaper/magazine    237
# Commercial broadcaster         33
# Tabloid newspaper              19
# Public broadcaster             12
# Done. batch_published_at=2026-03-27T06:37:12Z

# %%
# !python C:\code\news\ai-curated-news\backend\2embedding_and_cluster.py
# Out:
# 滚动窗口: 最近 24 小时
# 窗口开始(UTC): 2026-03-26T06:37:37Z
# 窗口结束(UTC): 2026-03-27T06:37:37Z
# 窗口原始数据量: 2093
# 清洗后数据量: 2093
# 识别到网址列: link
# 待处理新增标题数: 326
# active clusters 数量: 27
# 匹配到旧簇标题数: 13
# 未匹配标题数: 313
#
# === 本次结果 ===
# 新增入库到旧簇的标题数: 13
# 候选新簇二次对齐回旧簇的簇数: 1
# unmatched 写入标题数: 78
# 新建 cluster 数: 5
# 簇内二次分裂新增 cluster 数: 0
# cluster_size_history 新增记录数: 12
# cluster.sqlite 已更新。
# ...
#
# ...
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 8293.42it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#
# ...
# Batches: 100%|██████████| 6/6 [00:00<00:00,  8.35it/s]

# %%
# !python C:\code\news\ai-curated-news\backend\2llm_summarize.py
# Out:
# clusters_to_summarize=13 min_delta=3
# [1] cluster=31 size=44 status=ok
# url: https://www.lavozdegalicia.es/firmas/patricia-calveiro-iglesias
# output preview:
# 加西亚地区近期在多个领域呈现多元化发展态势：
# 1. **经济与能源**：风力发电项目因司法程序延迟停滞，科技企业依托本地特色推动创新，成为区域经济新增长点。
# 2. **社会议题**：安乐死实践引发对生命权的伦理讨论，同时新兴占房现象（租户后期索要赎金）凸显社会矛盾。
# 3. **文化与旅游**：通过神话漫画《Severina e a raíña dos trasnos》活化本土文化，结合阳台景观资源吸引游客，推动文旅融合。
# 4. **基础设施**：政府加速公路网络建设，旨在提升地区联通性及投资吸引力。
#
# 这一系列动态反映出加西亚在平衡传统与现代化、经济与社会需求方面的探索。
# --------------------------------------------------------------------------------
# [2] cluster=16 size=32 status=skip_error
# url: http://www.elpuntavui.cat/?task=mescriteri.mes&format=raw&criteri=subcanal&t=20260327024037&id=3376&itemidmes=1030&subsegment=7&count=6&start=8
# error: Model returned null-like content
# --------------------------------------------------------------------------------
# [3] cluster=19 size=22 status=ok
# ...
